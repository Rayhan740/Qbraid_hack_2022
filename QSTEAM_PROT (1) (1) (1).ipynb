# %% [markdown]
# # How Quantum Computing came to existense

# %% [markdown]
# "Classical physics" is the name for the set of rules that scientists came up with before the early 1900s, and it's really good at predicting the behavior of things like cricket ball and car engines. But the electron orbiting an atom is bit different. Around the early 1900s, scintist started being able to study things on the atomic scale. They found that really small things like atoms behave differently to the things we interact with our day-to-day lives and in certain cases the rules of classical physics weren’t quite right. The physics they had needed modifying, so the scientists came up with a more accurate set of rules which became known as “quantum physics”. 'Quantum mechanics' which is a part of Quantum Physics is the description of the behavior of matter and light in all in details and, in particular, of the happenings on an atomic scale. Things that are very small can act or behave like nothing that we have any direct experience about. We are talking about really small things like the range can be  10−10   𝑛𝑚 . Using the idea of Quantum mechanics the idea of "Quantum Computers" were proposed in the 1980s by Richard Feynman and Yuri Manin. The intuition behind quantum computing stemmed from what was often seen as one of the greatest embarrassments of physics: remarkable scientific progress faced with an inability to model even simple systems. This is because simulating systems of even a few dozen interacting particles requires more computing power than any conventional computer can provide over thousands of years!

# %% [markdown]
# # How Quantum Computing Works

# %% [markdown]
# The power of quantum computing rests on two cornerstones of Quantum Mechanics, namely interference and entanglement that highlight the wave and particle like aspects of quantum computation

# %% [markdown]
# ## Interference

# %% [markdown]
# Like a classical computer, a quantum computer operates on bits. However, while classical bits can only be found in the states 0 and 1, a quantum bit, or qubit, can represent the values 0 and 1, or linear combinations of both. These linear combinations are known as superpositions (or superposition states). What does this linear combination means?? we can think of linear combination suppose we have two variable $x$ and $y$ and if we can represent it with a new one like $$  z = ax + by $$

# %% [markdown]
# ![Quantum-1.png](attachment:8811bc06-162b-45a0-9580-c631552ff576.png)
#          Pic: Demonstration on Classical and Quantum Bit

# %% [markdown]
# To see how interference is utilized in quantum computation we have to turn to a classial analog: Noise cancellation. Noise cancellation, as done in noise cancellation headphones for example,is performed by employing superposition and the principle of interference to reduce the amplitude of unwanted noise by generating a tone of approximately the same frequency and amplitude, but out of phase by a value of $π$

# %% [markdown]
# ![noise_cancel.png](attachment:ad5b9ba5-92ff-4789-932c-560e1c26f8c8.png)
#
# Fig:  1 Approximate cancellation of a noise signal by a tone of nearly equal amplitude and offset by a phase of ~$π$

# %% [markdown]
# As shown above, when the phase difference is close to an odd multiple of , the superposition of the two waves results in interference

# %% [markdown]
# ## Quantum Entanglement

# %% [markdown]
# We are going to discuss about quantum entanglement in details as the problem is to find out an entangled state with multiple qubits. The spookines of quantum entanglement emerges from the reality of quantum superposition, and was clear to the founding fathers of quantum mechanics who developed the theory in the 1920s to 1930s. To create entangled particles we essentially break a system into two, where the sum of the parts is known. For example, we can split of zero into two particles that necessarily will have opposite spins so that their sum is zero. Just like electron and positron. Before going to any further details we need to have some basic Linear Algebraic knowledge to understand Quantum Computation.

# %% [markdown]
# ## Basic Linear Algebra

# %% [markdown]
# As we represent bits in classical computer as 0 and 1. We represents our Quantum bit or qubit as the vector representation of $|0 \rangle$ and $|1 \rangle$. Which are vertical list of numbers:  $$ |0 \rangle =  \begin{bmatrix} 1 \\ 0 \end{bmatrix} , |1 \rangle = \begin{bmatrix} 0 \\ 1 \end{bmatrix}$$

# %% [markdown]
# A generic qubit with amplitudes ${\alpha}$ and ${\beta}$ would be:  $$ \begin{align} |{\psi} \rangle = {\alpha}|0 \rangle + {\beta}|1 \rangle
#  = {\alpha} \begin{bmatrix} 1 \\ 0 \end{bmatrix} + {\beta} \begin{bmatrix} 0 \\ 1 \end{bmatrix}
#  = \begin{bmatrix} {\alpha} \\ {\beta} \end{bmatrix} \end{align}$$

# %% [markdown]
# we can't represent any vector as quantum state there are some rule that need to be followed and one of them is the vector state need to be normalized that means $$ {\alpha}^2 + {\beta}^2 = 1 $$

# %% [markdown]
# One types of product we need to know for our computation is outer product. Suppose we have two $|0 \rangle $ state so there outer product will be $$ |0 \rangle |0 \rangle = |0 \rangle {\otimes} |0 \rangle = \begin{bmatrix} 1 \begin{bmatrix} 1 \\ 0 \end{bmatrix} \\ 0 \begin{bmatrix} 1 \\ 0 \end{bmatrix} \end{bmatrix} = \begin{bmatrix} 1 \\ 0 \\ 0 \\ 0 \end{bmatrix}  = |00 \rangle $$

# %% [markdown]
# now we are ready for going into computation where we are going to learn how we can create an entangle state with multiple qubit. We know that there exist quantum states that can not be factored into product state. For example, with two qubits  , $$ \begin{align} |{\phi}^+ \rangle = \frac{1}{\sqrt{2}} (|00 \rangle + |11 \rangle) \end{align} $$

# %% [markdown]
# Which cannot be written as $ |{\psi_{1}} \rangle |{\psi_{0}} \rangle$. As a proof let's try to write it as a product state using the procedure from the Linear Algebra section:
# $$ |{\psi_{1}} \rangle |{\psi_{0}} \rangle  = (\alpha_{1}|0 \rangle + \beta_{1}|1 \rangle)(\alpha_{0}|0 \rangle + \beta_{0}|1 \rangle) =  {\alpha_{1}}{\alpha_{0}}|00 \rangle +  {\alpha_{1}}{\beta_{0}}|01 \rangle +  {\beta_{1}}{\alpha_{0}}|10 \rangle +  {\beta_{1}}{\beta_{0}}|11 \rangle $$

# %% [markdown]
# Matching the coefficient , we get $$ {\alpha_{1}}{\alpha_{0}} = {\frac{1}{\sqrt{2}}},   {\alpha_{1}}{\beta_{0}} = 0, {\beta_{1}}{\alpha_{0}} = 0, {\beta_{1}}{\beta_{0}} =  {\frac{1}{\sqrt{2}}} $$

# %% [markdown]
# The Second equation requires $\alpha_{1}  = 0$ or $\beta_{0} = 0$. If $ \alpha_{1} = 0$, then the first equation gives $0 = \frac{1}{\sqrt{2}}$, which is false. If $ \beta_{0} = 0 $, then the fourth equation gives   $0 = \frac{1}{\sqrt{2}}$. Thus, there is no solution to these four equations, so $  |{\phi}^+ \rangle $ cannot be written as a product state. It is an entangled state. <b>This property that the state of the qubits are interwined is called entanglement</b>. Since an entangle state cannot be factored, a general entangled state of n qubits whould have $N = 2^n$ amplitueds $c_{0}$ through $c_{N-1}$: $$ |{\psi} \rangle = \sum \limits_{j=0}^{N-1} c_{j}|j \rangle = c_{0}|0 \rangle + c_{1} |1 \rangle +  .... + c_{N-1}|N-1 \rangle = \begin{bmatrix} c_{0} \\ c_{1} \\ ... \\ c_{N-1} \end{bmatrix} $$

# %% [markdown]
# We know for two qubit the circuit that will give us an entangled state is:

# %%
# For two qubits 
from qiskit import *

qc = QuantumCircuit(2,2)
qc.h(0)
qc.cx(0,1)
qc.draw()

# %% [markdown]
# In the upper circuit we have seen that we used a <b> Hadamard gate </b> and a <b> CNOT gate </b> where the control is in 0 qubit and the target is in 1. The reason for using the Hadamard gate  we will be getting superposition state of two qubits like: $$ \frac{1}{\sqrt{2}} (|00 \rangle + |01 \rangle) $$ and after that when we are going to use CNOT gate then if the control is 1 then the target will be 1 as well. So, the final state will be: $$ \frac{1}{\sqrt{2}} (|00 \rangle + |11 \rangle) $$

# %% [markdown]
# So, I guess we get the idea of how we can create an entangled state so let's create an entangled state with multiple qubit.

# %% [markdown]
# ## Creating entanglement with multiple qubits

# %%
from qiskit import * # From qiskit import everything

nqubits = 3 # Taking 3 qubits
nclassical = 3 # Taking 3 classical bits
circuits = QuantumCircuit(nqubits,nclassical) # define a QuantumCircuit with 3 Qubit and 3 Classical bit
circuits.h(0)  # Using ane hadamard gate to create a superposition state
circuits.cx(0,1) # Using two CNOT gate so that we can create a Bell state or entangled state
circuits.cx(1,2) 
circuits.measure([0,1,2],[0,1,2]) # Measuring the circuit

# %%
# Here we can see the circuit representation of our code above
# %matplotlib inline
circuits.draw(output='mpl')

# %% [markdown]
# From the circuit above we can see that we have used one hadamard gate and two CNOT gate. Let's check the statevector that we are going to get from this circuit:

# %%
from qiskit.quantum_info import Statevector

nqubits = 3
nclassical = 3
circuits = QuantumCircuit(nqubits,nclassical)
circuits.h(0)
circuits.cx(0,1)
circuits.cx(1,2)

ket = Statevector(circuits)
ket.draw(output='latex')
# Out:
# $$\frac{\sqrt{2}}{2} |000\rangle+\frac{\sqrt{2}}{2} |111\rangle$$

# %% [markdown]
# From the statevector we can say that we cannot get the product state of $|{\psi_{0}} \rangle |{\psi_{1}} \rangle |{\psi_{2}} \rangle$. So, we can surely say that the statevector that is being shown in above is an entangled state. Now let's see verify our answer in local simulator and then plot the histogram $:$

# %%
from qiskit.visualization import plot_histogram 


nqubits = 3
nclassical = 3
circuits = QuantumCircuit(nqubits,nclassical)
circuits.h(0)
circuits.cx(0,1)
circuits.cx(1,2)
circuits.measure([0,1,2],[0,1,2]) 

simulator = Aer.get_backend('qasm_simulator') # Taking qasm_simulator as local simulator
sim_result = execute(circuits, backend=simulator, shots =1024).result() # Executing the circuit and getting the result
plot_histogram(sim_result.get_counts(circuits))
# Out:
# <frozen importlib._bootstrap>:219: RuntimeWarning: scipy._lib.messagestream.MessageStream size changed, may indicate binary incompatibility. Expected 56 from C header, got 64 from PyObject

# %% [markdown]
# So,from above we can see the probability of getting  $|000 \rangle$ and $|111 \rangle$. But now we are going to run it on a real Quantum Computer. Let's see the results for a real quantum computer $:$

# %% [markdown]
# ### Running our code on IBM Quantum Computer

# %%
from qiskit import IBMQ

# %%
IBMQ.load_account()
# Out:
# ibmqfactory.load_account:WARNING:2022-11-04 11:29:00,855: Credentials are already in use. The existing account in the session will be replaced.
# <AccountProvider for IBMQ(hub='ibm-q', group='open', project='main')>

# %%
from qiskit.providers.ibmq import IBMQ, least_busy
provider = IBMQ.get_provider('ibm-q')
device = least_busy(provider.backends(filters=lambda x: not x.configuration().simulator))
print(f'Running on {device.name()}')
# Out:
# Running on ibmq_belem

# %%
# Forming the program so that the device can run it
# It is known as transpiling
from qiskit import transpile
transpiled_qc = transpile(circuits, device)

# %%
# Sending the program off to the IBM Quantum to run on a real device
# and monitoring its status

from qiskit.tools import job_monitor
job = device.run(transpiled_qc)
job_monitor(job)
# Out:
# Job Status: job has successfully run

# %%
# Plotting the result as histogram
from qiskit.visualization import plot_histogram
plot_histogram(job.result().get_counts())

# %% [markdown]
# So, now we can see that there are total 8 different state and also we should be getting only two state that is $|000 \rangle$ and $|111 \rangle$ but we are getting more than that. So, there is may be some problem but what is it? Yeah! it's noise 😅. Because of noise in the measurement we are getting those other state also in real quantum computer what about if we try to run it on a different quantum computer ?? Let's try it out $:$

# %% [markdown]
# ### Running Our Code on Amazon Braket

# %%
# general imports
import matplotlib.pyplot as plt
# %matplotlib inline

# AWS imports: Import Braket SDK modules
from braket.circuits import Circuit
from braket.devices import LocalSimulator

bell = Circuit().h(0).cnot(control=0, target=1).cnot(control=1, target=2)
# set up device
device = LocalSimulator()

# run circuit
result = device.run(bell, shots=1024).result()
# get measurement shots
counts = result.measurement_counts
# print counts
print(counts)
# Out:
# Counter({'000': 513, '111': 511})

# %%
# plot using Counter on Local simulator 
plt.bar(counts.keys(), counts.values());
plt.xlabel('bitstrings');
plt.ylabel('counts');

# %% [markdown]
# We can see that on local simulator the outcome is same that is the superposition of $|000 \rangle $ and $|111 \rangle $ so let's try on real Quantum Computer $:$

# %%
# general imports
import numpy as np
import matplotlib.pyplot as plt
# magic word for producing visualizations in notebook
# %matplotlib inline
import string
import time

# AWS imports: Import Braket SDK modules
from braket.circuits import Circuit, Gate, Instruction, circuit, Observable
from braket.devices import LocalSimulator
from braket.aws import AwsDevice, AwsQuantumTask
s3_folder = ("dummy_variable", "dummy_variable")

# %%
# print all (the usual suspects) available gates currently available within SDK
gate_set = [attr for attr in dir(Gate) if attr[0] in string.ascii_uppercase]
print('Gate set supported by SDK:\n', gate_set)
print('\n') 

# the Rigetti device
device = AwsDevice("arn:aws:braket:us-west-1::device/qpu/rigetti/Aspen-M-1")
supported_gates = device.properties.action['braket.ir.jaqcd.program'].supportedOperations
# print the supported gate set
print('Gate set supported by the Rigetti device:\n', supported_gates)
print('\n')
# Out:
# Gate set supported by SDK:
#  ['CCNot', 'CNot', 'CPhaseShift', 'CPhaseShift00', 'CPhaseShift01', 'CPhaseShift10', 'CSwap', 'CV', 'CY', 'CZ', 'ECR', 'H', 'I', 'ISwap', 'PSwap', 'PhaseShift', 'Rx', 'Ry', 'Rz', 'S', 'Si', 'Swap', 'T', 'Ti', 'Unitary', 'V', 'Vi', 'X', 'XX', 'XY', 'Y', 'YY', 'Z', 'ZZ']
#
#
# Gate set supported by the Rigetti device:
#  ['cz', 'xy', 'ccnot', 'cnot', 'cphaseshift', 'cphaseshift00', 'cphaseshift01', 'cphaseshift10', 'cswap', 'h', 'i', 'iswap', 'phaseshift', 'pswap', 'rx', 'ry', 'rz', 's', 'si', 'swap', 't', 'ti', 'x', 'y', 'z', 'start_verbatim_box', 'end_verbatim_box']

# %%
# set up device
rigetti = AwsDevice("arn:aws:braket:us-west-1::device/qpu/rigetti/Aspen-M-2")

# create a clean circuit with no result type attached.(This is because some result types are only supported when shots=0)
bell = Circuit().h(0).cnot(0, 1).cnot(1,2)  

# add the Z \otimes Z expectation value
bell.expectation(Observable.Z() @ Observable.Z() @ Observable.Z(), target=[0,1,2])

# run circuit 
rigetti_task = rigetti.run(bell, s3_folder,shots=1024)

# get id and status of submitted task
rigetti_task_id = rigetti_task.id
rigetti_status = rigetti_task.state()
print('ID of task:', rigetti_task_id)
print('Status of task:', rigetti_status)
# Out:
# ID of task: arn:aws:braket:us-west-1:592242689881:quantum-task/7a371306-cd94-414d-a5d7-bc9bf5a5c8aa
# Status of task: CREATED

# %%
# print status
status = rigetti_task.state()
print('Status of (reconstructed) task:', status)
# Out:
# Status of (reconstructed) task: QUEUED

# %%
# recover task
task_load = AwsQuantumTask(arn="arn:aws:braket:us-west-1:592242689881:quantum-task/bc713542-c665-4ee1-aa8a-796cb7f88647")

# print status
status = task_load.state()
print('Status of (reconstructed) task:', status)
print('\n')
# wait for job to complete
# terminal_states = ['COMPLETED', 'FAILED', 'CANCELLED']
if status == 'COMPLETED':
    # get results
    results = task_load.result()
    # print(results)
    
    # get all metadata of submitted task
    metadata = task_load.metadata()
    # example for metadata
    shots = metadata['shots']
    machine = metadata['deviceArn']
    # print example metadata
    print("{} shots taken on machine {}.\n".format(shots, machine))
    
    # get measurement counts
    counts = results.measurement_counts
    print('Measurement counts:', counts)

    # plot results: see effects of noise
    plt.bar(counts.keys(), counts.values())
    plt.xlabel('bitstrings')
    plt.ylabel('counts')
    plt.tight_layout()
    plt.savefig('AWS_QC_results.png', dpi=700)
    
elif status in ['FAILED', 'CANCELLED']:
    # print terminal message 
    print('Your task is in terminal status, but has not completed.')

else:
    # print current status
    print('Sorry, your task is still being processed and has not been finalized yet.')

# %% [markdown]
# We can see from above on real Quantum Computer we are not only getting this $|000 \rangle$ , $|111 \rangle $ states but also getting other 6 states and this is happenning  because of noise. So, now let's investigate noise.

# %% [markdown]
# # Let's investigate the Noise in this circuit

# %% [markdown]
# The effect of noise is to give us outputs that are not quite correct. The effect of noise that occurs throughout a computation will be quite complex in general, as one would have to consider how each gate transforms the effect of each error. A simpler form that we can think off during the final measurement. At this point, the only job remianing in th circuit is to extract a bit string as an output. For an n qubit final measurement, this means extracting one of the $2^n$ possible n bit strings. As a simple model of noise in this process, we can imagine that the measurement first selects one of these outputs in a perfect and noiseless manner, and then noise subsequently causes this perfect output to be randomly pertubed before it is return to the user. Let's try to investigate noise for our model above. As we have seen that we are getting other state like $|001 \rangle$, $|010 \rangle$, $|001 \rangle$ , $|011 \rangle$, $|100 \rangle$, $|110 \rangle $ which is due to noise. So , let's create a noise model which will be giving us this kind of output and then try to mitigate the noise.

# %%
from qiskit import * # From qiskit import everything

nqubits = 3 # Taking 3 qubits
nclassical = 3 # Taking 3 classical bits
circuits = QuantumCircuit(nqubits,nclassical) # define a QuantumCircuit with 3 Qubit and 3 Classical bit
circuits.h(0)  # Using ane hadamard gate to create a superposition state
circuits.cx(0,1) # Using two CNOT gate so that we can create a Bell state or entangled state
circuits.cx(1,2) 

circuits.barrier()

circuits.delay(250,unit='us')

circuits.barrier()

circuits.measure([0,1,2],[0,1,2]) # Measuring the circuit

# %%
circuits.draw()

# %%
# Let's try to run this on Quantum Computer

from qiskit import IBMQ

IBMQ.load_account()

from qiskit.providers.ibmq import IBMQ, least_busy
provider = IBMQ.get_provider('ibm-q')
device = least_busy(provider.backends(filters=lambda x: not x.configuration().simulator))
print(f'Running on {device.name()}')

# Forming the program so that the device can run it
# It is known as transpiling
from qiskit import transpile
transpiled_qc = transpile(circuits, device)


# Sending the program off to the IBM Quantum to run on a real device
# and monitoring its status

from qiskit.tools import job_monitor
job = device.run(transpiled_qc)
job_monitor(job)

# Plotting the result as histogram
from qiskit.visualization import plot_histogram
plot_histogram(job.result().get_counts())
# Out:
# ibmqfactory.load_account:WARNING:2022-11-04 11:33:34,319: Credentials are already in use. The existing account in the session will be replaced.
# Running on ibmq_belem
# Job Status: job has successfully run

# %% [markdown]
# Lets try different delay time and then draw Decoherence vs time plot

# %% [markdown]
# References $:$
# <ol>
#
# <li><a href= 'https://bayanbox.ir/view/7605377025000428006/The-Feynman-Lectures-on-Physics-Vol.-III-Quantum-Mechanics.pdf'>Feynmann Physics Vol III</a>
#
# <li><a href='https://qiskit.org/textbook/preface.html'>Qiskit Textbook</a>
#
# <li><a href='https://learn.microsoft.com/en-us/azure/quantum/overview-understanding-quantum-computing'>Microsoft Quantum Azure</a>
#
# <li> <a href='https://www.thomaswong.net/introduction-to-classical-and-quantum-computing-1e3p.pdf'>Intoduction to Classical and  Quantum Computing by Thomas G Wong</a>
#
#
# </ol>
